# %% [markdown]
# The employee dataset analysed here consists of 458 rows and 9 columns, which contains information about Name, Team, Number, Position, Age, Height, Weight, College and Salary.

# %% [markdown]
# **Importing necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading data into a pandas DataFrame**

# %%
df = pd.read_csv('C:\\Entri\\data sets\\myexcel - myexcel.csv.csv') 
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# **Information about the dataset**

# %%
df.dtypes #Displaying data type of each column of the dataset
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
df.info() #displaying information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# ## Preprocessing the dataset

# %% [markdown]
# **Identifying duplicate records in the dataset**

# %%
df.duplicated() #checking for duplicates in dataset
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df[df.duplicated()] #Detecting duplicate rows
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %% [markdown]
# There are no duplicate rows in the dataset.

# %% [markdown]
# **Identifying null values in the dataset**

# %%
df.isnull() #to show if null values are present
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %%
#check for null values in each column
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#Rectifying error in values of 'Height' column as height values in the dataset are incorrect.
import random
ht=[]
#creating a list of random numbers between 150 and 180
for i in range(0,458):
    v=random.randint(150,180)
    ht.append(v)
ht
# Out:
# [167,
#  180,
#  153,
#  162,
#  154,
#  151,
#  157,
#  168,
#  163,
#  174,
#  152,
#  164,
#  150,
#  180,
#  171,
#  159,
#  171,
#  175,
#  164,
#  175,
#  173,
#  156,
#  174,
#  155,
#  152,
#  163,
#  180,
#  150,
#  179,
#  166,
#  166,
#  155,
#  174,
#  160,
#  178,
#  176,
#  156,
#  174,
#  152,
#  173,
#  162,
#  170,
#  180,
#  161,
#  169,
#  173,
#  175,
#  169,
#  173,
#  179,
#  167,
#  177,
#  168,
#  165,
#  178,
#  152,
#  165,
#  167,
#  163,
#  158,
#  156,
#  174,
#  161,
#  176,
#  164,
#  150,
#  167,
#  165,
#  156,
#  169,
#  178,
#  180,
#  164,
#  180,
#  155,
#  167,
#  165,
#  158,
#  165,
#  167,
#  177,
#  179,
#  168,
#  158,
#  158,
#  166,
#  150,
#  163,
#  171,
#  167,
#  151,
#  159,
#  162,
#  160,
#  171,
#  151,
#  170,
#  163,
#  157,
#  180,
#  167,
#  178,
#  171,
#  150,
#  150,
#  163,
#  173,
#  160,
#  158,
#  167,
#  164,
#  155,
#  160,
#  168,
#  159,
#  172,
#  155,
#  161,
#  173,
#  168,
#  162,
#  171,
#  176,
#  173,
#  165,
# ...

# %%
#assigning list created above to the 'Height' column of the dataset
df['Height']=ht
df[['Name','Height']]
# Out:
#               Name  Height
# 0    Avery Bradley     167
# 1      Jae Crowder     180
# 2     John Holland     153
# 3      R.J. Hunter     162
# 4    Jonas Jerebko     154
# ..             ...     ...
# 453   Shelvin Mack     160
# 454      Raul Neto     154
# 455   Tibor Pleiss     165
# 456    Jeff Withey     159
# 457       Priyanka     172
#
# [458 rows x 2 columns]

# %% [markdown]
# **1.a)Number of employees in each team**

# %%
teamwise_count=pd.DataFrame(df['Team'].value_counts()).reset_index()
teamwise_count.columns=['Team','No of employees']
teamwise_count
# Out:
#                       Team  No of employees
# 0     New Orleans Pelicans               19
# 1        Memphis Grizzlies               18
# 2                Utah Jazz               16
# 3          New York Knicks               16
# 4          Milwaukee Bucks               16
# 5            Brooklyn Nets               15
# 6   Portland Trail Blazers               15
# 7    Oklahoma City Thunder               15
# 8           Denver Nuggets               15
# 9       Washington Wizards               15
# 10              Miami Heat               15
# 11       Charlotte Hornets               15
# 12           Atlanta Hawks               15
# 13       San Antonio Spurs               15
# 14         Houston Rockets               15
# 15          Boston Celtics               15
# 16          Indiana Pacers               15
# 17         Detroit Pistons               15
# 18     Cleveland Cavaliers               15
# 19           Chicago Bulls               15
# ...

# %% [markdown]
# **1.b)Percentage splitting of employees in each team with respect to the total employees**

# %%
#finding percentage of employees w.r.t total employees
team_percent=[]
for i in range(0,30):  
    team_percent.append(round((teamwise_count['No of employees'].iloc[i]/sum(teamwise_count['No of employees']))*100,2))
teamwise_count['Percentage']=team_percent
teamwise_count
# Out:
#                       Team  No of employees  Percentage
# 0     New Orleans Pelicans               19        4.15
# 1        Memphis Grizzlies               18        3.93
# 2                Utah Jazz               16        3.49
# 3          New York Knicks               16        3.49
# 4          Milwaukee Bucks               16        3.49
# 5            Brooklyn Nets               15        3.28
# 6   Portland Trail Blazers               15        3.28
# 7    Oklahoma City Thunder               15        3.28
# 8           Denver Nuggets               15        3.28
# 9       Washington Wizards               15        3.28
# 10              Miami Heat               15        3.28
# 11       Charlotte Hornets               15        3.28
# 12           Atlanta Hawks               15        3.28
# 13       San Antonio Spurs               15        3.28
# 14         Houston Rockets               15        3.28
# 15          Boston Celtics               15        3.28
# ...

# %% [markdown]
# **Bar chart of percentage of employees in each team**

# %%
x = teamwise_count['Percentage']
y = teamwise_count['Team']

fig, ax = plt.subplots(figsize=(12, 8), dpi=100)
bar_width = 0.8 

ax.barh(y, x, edgecolor='black', height=bar_width)

ax.set_xlabel("Percentage")
ax.set_ylabel("Teams")
ax.set_title("Percentage of Employees in Each Team")


ax.set_yticks(np.arange(len(y)))
ax.set_yticklabels(y)

plt.tight_layout()
plt.show()

# %% [markdown]
# **2. Segregating the employees w.r.t different positions**

# %%
# Extract unique positions from dataframe and create a seperate emp_position dataframe
unique_positions = df['Position'].unique()
emp_position = pd.DataFrame(columns=unique_positions)

# Iterate over the positions and assign employee names to corresponding columns
for position in unique_positions:
    employee_names = df.loc[df['Position'] == position, 'Name']
    if len(employee_names) > 0:
        emp_position[position] = employee_names.reset_index(drop=True)
emp_position
# Out:
#                PG                      SF                SG                PF
# 0   Avery Bradley             Jae Crowder      John Holland     Jonas Jerebko  \
# 1    Terry Rozier  Thanasis Antetokounmpo       R.J. Hunter      Amir Johnson
# 2    Marcus Smart         Carmelo Anthony       Evan Turner     Jordan Mickey
# 3   Isaiah Thomas        Cleanthony Early       James Young  Chris McCullough
# 4    Jarrett Jack            Lance Thomas  Bojan Bogdanovic       Willie Reed
# ..            ...                     ...               ...               ...
# 87  Brian Roberts                     NaN       Mike Miller   Nemanja Bjelica
# 88     Trey Burke                     NaN    JaKarr Sampson     Kevin Garnett
# 89     Dante Exum                     NaN      Axel Toupane     Adreian Payne
# 90   Shelvin Mack                     NaN    Andrew Wiggins        Greg Smith
# 91      Raul Neto                     NaN        Randy Foye     Nick Collison
#
#                   C
# ...

# %% [markdown]
# **3.Age group to which most employees belong to**

# %%
#finding minimum and maximum of age
print("Minimum age: ",df['Age'].min())
print("Maximum age: ",df['Age'].max())
# Out:
# Minimum age:  19
# Maximum age:  40

# %%
#Classifying employees to different age groups and finding the count of each age group
bins = [20, 25,30,35,40]
df['Age Group'] = pd.cut(df['Age'], bins=bins)
age_group_counts = df['Age Group'].value_counts()
print("Employees of different age groups:\n",age_group_counts)

# Age group with the maximum count
max_age_group = age_group_counts.idxmax()
print(f"The age group with the maximum number of employees is {max_age_group}")

# Visualizing the age groups and their employee counts
age_group_counts.plot(kind='bar')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Age Group')
plt.show()
# Out:
# Employees of different age groups:
#  Age Group
# (20, 25]    179
# (25, 30]    167
# (30, 35]     68
# (35, 40]     23
# Name: count, dtype: int64
# The age group with the maximum number of employees is (20, 25]

# %% [markdown]
# **4.Team and position for which spending in terms of salary is high**

# %%
sal_max=df['Salary'].max()
sal_max
# Out:
# 25000000.0

# %%
df.loc[df['Salary']==sal_max,['Team','Position','Salary']]
# Out:
#                    Team Position      Salary
# 109  Los Angeles Lakers       SF  25000000.0

# %% [markdown]
# **5.Correlation between age and salary**

# %%
df1=df[['Age','Salary']]
df1
# Out:
#      Age     Salary
# 0     25  7730337.0
# 1     25  6796117.0
# 2     27        NaN
# 3     22  1148640.0
# 4     29  5000000.0
# ..   ...        ...
# 453   26  2433333.0
# 454   24   900000.0
# 455   26  2900000.0
# 456   26   947276.0
# 457   25   947276.0
#
# [458 rows x 2 columns]

# %%
#Visual representation of age-salary correlation using heatmap

correlation = df1[['Age', 'Salary']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True,cmap='coolwarm',linewidths=0.5)
plt.title("Correlation between Age and Salary")
plt.show()

# %% [markdown]
# Above heat map shows that the correlation between Age and Salary values is 0.21. This suggests that there is a positive, but a weak correlation between the variables.Hence, cannot form a definitive conclusion about the relationship between age and salary.There may be other factors, which may influence salary and also,there can be considerable variation in salary within each age group. This can also be further verified using the following salary distribution line graph.

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight
# 0  Avery Bradley  Boston Celtics       0       PG   25     167     180  \
# 1    Jae Crowder  Boston Celtics      99       SF   25     180     235
# 2   John Holland  Boston Celtics      30       SG   27     153     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     162     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     154     231
#
#              College     Salary Age Group
# 0              Texas  7730337.0  (20, 25]
# 1          Marquette  6796117.0  (20, 25]
# 2  Boston University        NaN  (25, 30]
# 3      Georgia State  1148640.0  (20, 25]
# 4                NaN  5000000.0  (25, 30]

# %% [markdown]
# **Line graph showing average salary distribution across different age groups of the dataset**

# %%
# Grouping the data by 'Age Group' and calculate average salary
grouped_data = df.groupby('Age Group')['Salary'].mean()
# Extracting age groups and average salaries
age_groups = grouped_data.index.astype(str)
average_salaries = grouped_data.values

# Plotting the line chart
plt.plot(age_groups, average_salaries,marker='^')
plt.xlabel('Age Group')
plt.ylabel('Average Salary in Millions')
plt.title('Average salary distribution across age groups')
plt.grid(True)
plt.show()
